# %% [markdown]
# # Conduct a correlation analysis on SPI Score.

# %% [markdown]
# ## Scope
# - [x] Use heatmap to see how every col relates to every other col.
# - [x] Select top 4 highly corelated variables to spi_score.

# %% [markdown]
# ## Summary
# - Overall all the columns are highly correlated to spi_score as all of them have correlation value > 0.5
# - Top 4 Highly correlated attributes to spi score are:
#     1. Wellbeing
#     2. Access to information and communication
#     3. Opportunity
#     4. Access to advanced education
# - All the 4 mentioned attributes have correlation > 0.9
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Read csv
df = pd.read_csv('C:/Users/Tanish/Desktop/SPI-Analysis-Project/Data/new_spi.csv')

# %%
# Preview
df.head()
# Out:
#    spi_rank      country  spi_score  basic_human_needs  wellbeing  \
# 0         1       Norway      92.63              95.29      93.30
# 1         2      Finland      92.26              95.62      93.09
# 2         3      Denmark      92.15              95.30      92.74
# 3         4      Iceland      91.78              96.66      93.65
# 4         5  Switzerland      91.78              95.25      93.80
#
#    opportunity  basic_nutri_med_care  water_sanitation  shelter  \
# 0        89.30                 98.81             98.33    93.75
# 1        88.07                 98.99             99.26    96.48
# 2        88.41                 98.62             98.21    94.92
# 3        85.04                 98.99             98.82    93.16
# 4        86.28                 98.72             98.96    92.97
#
#    personal_safety  access_basic_knowledge  access_info_comm  health_wellness  \
# 0            90.29                   98.66             95.80            89.32
# ...

# %%
# Shape
df.shape
# Out:
# (168, 19)

# %% [markdown]
# ### Figure out the top 4 variables which have the highest effect on spi_Score

# %%
# Filter numeric columns only
numeric_df = df.select_dtypes(include='number')

# %%
# Calculate the correlation matrix
correlation_matrix = numeric_df.corr()

# %%
correlation_matrix
# Out:
#                          spi_rank  spi_score  basic_human_needs  wellbeing  \
# spi_rank                 1.000000  -0.991792          -0.918310  -0.977923
# spi_score               -0.991792   1.000000           0.931309   0.982928
# basic_human_needs       -0.918310   0.931309           1.000000   0.892856
# wellbeing               -0.977923   0.982928           0.892856   1.000000
# opportunity             -0.929067   0.934230           0.755621   0.908485
# basic_nutri_med_care    -0.869686   0.882524           0.967305   0.853781
# water_sanitation        -0.875412   0.883324           0.969328   0.846952
# shelter                 -0.815916   0.828981           0.943888   0.799977
# personal_safety         -0.786567   0.802462           0.737791   0.754645
# access_basic_knowledge  -0.876136   0.889641           0.873431   0.898555
# access_info_comm        -0.925618   0.937408           0.881768   0.932662
# ...

# %%
# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
# Get the absolute correlation values with 'spi_score'
correlation_with_spi = correlation_matrix['spi_score'].abs().sort_values(ascending=False)

# %%
correlation_with_spi
# Out:
# spi_score                  1.000000
# spi_rank                   0.991792
# wellbeing                  0.982928
# access_info_comm           0.937408
# opportunity                0.934230
# access_adv_edu             0.932358
# basic_human_needs          0.931309
# personal_freedom_choice    0.919743
# health_wellness            0.909080
# access_basic_knowledge     0.889641
# water_sanitation           0.883324
# basic_nutri_med_care       0.882524
# shelter                    0.828981
# personal_safety            0.802462
# inclusiveness              0.733665
# personal_rights            0.716326
# env_quality                0.666195
# Name: spi_score, dtype: float64

# %%
# Select the top 4 variables with the highest impact on 'spi_score'
top_4_impact_variables = correlation_with_spi[2:6]  # Excluding 'spi_score' and 'spi_rank'

top_4_impact_variables
# Out:
# wellbeing           0.982928
# access_info_comm    0.937408
# opportunity         0.934230
# access_adv_edu      0.932358
# Name: spi_score, dtype: float64

# %%
# Mention the variable names you want to include in the heatmap
top_4_variables = ['spi_score', 'access_info_comm', 'wellbeing', 'opportunity','access_adv_edu']

# %%
# Filter the correlation matrix to include only the mentioned variables
filtered_corr_matrix = correlation_matrix.loc[top_4_variables, top_4_variables]

# %%
# Create the heatmap for the mentioned variables using Seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(filtered_corr_matrix, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
plt.title("Correlation Heatmap of Most Affecting Variables")
plt.show()
